# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
class BinaryClassifier(nn.Module):
    def __init__(self):
        super(BinaryClassifier, self).__init__()
        self.linear = nn.Linear(2, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.linear(x)
        x = self.sigmoid(x)
        return x

# %%
x_data = [[1, 2], [2, 3], [3, 1], [4, 3], [5, 3], [6, 2]]
y_data = [[0], [0], [0], [1], [1], [1]]
x_train = torch.FloatTensor(x_data)
y_train = torch.FloatTensor(y_data)

# %%
model = BinaryClassifier()
optimizer = optim.SGD(model.parameters(), lr=1)

nb_epochs = 1000
for epoch in range(nb_epochs+1):

    hypothesis = model(x_train)
    cost = F.binary_cross_entropy(hypothesis, y_train)

    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    if epoch % 10 == 0:
        prediction = hypothesis >= torch.FloatTensor([0.5]) # 예측값이 0.5를 넘으면 True로 간주
        correct_prediction = prediction.float() == y_train # 실제값과 일치하는 경우만 True로 간주
        accuracy = correct_prediction.sum().item() / len(correct_prediction) # 정확도를 계산
        print('Epoch {:4d}/{} Cost: {:.6f} Accuracy {:2.2f}%'.format( # 각 에포크마다 정확도를 출력
            epoch, nb_epochs, cost.item(), accuracy * 100,
        ))
# Out:
# Epoch    0/1000 Cost: 0.675809 Accuracy 50.00%
# Epoch   10/1000 Cost: 0.454910 Accuracy 83.33%
# Epoch   20/1000 Cost: 0.659973 Accuracy 83.33%
# Epoch   30/1000 Cost: 0.530546 Accuracy 83.33%
# Epoch   40/1000 Cost: 0.441737 Accuracy 83.33%
# Epoch   50/1000 Cost: 0.358053 Accuracy 83.33%
# Epoch   60/1000 Cost: 0.279772 Accuracy 83.33%
# Epoch   70/1000 Cost: 0.213396 Accuracy 83.33%
# Epoch   80/1000 Cost: 0.170066 Accuracy 100.00%
# Epoch   90/1000 Cost: 0.150297 Accuracy 100.00%
# Epoch  100/1000 Cost: 0.139271 Accuracy 100.00%
# Epoch  110/1000 Cost: 0.130127 Accuracy 100.00%
# Epoch  120/1000 Cost: 0.122135 Accuracy 100.00%
# Epoch  130/1000 Cost: 0.115085 Accuracy 100.00%
# Epoch  140/1000 Cost: 0.108820 Accuracy 100.00%
# Epoch  150/1000 Cost: 0.103216 Accuracy 100.00%
# Epoch  160/1000 Cost: 0.098173 Accuracy 100.00%
# Epoch  170/1000 Cost: 0.093612 Accuracy 100.00%
# Epoch  180/1000 Cost: 0.089465 Accuracy 100.00%
# Epoch  190/1000 Cost: 0.085679 Accuracy 100.00%
# Epoch  200/1000 Cost: 0.082208 Accuracy 100.00%
# Epoch  210/1000 Cost: 0.079015 Accuracy 100.00%
# Epoch  220/1000 Cost: 0.076066 Accuracy 100.00%
# Epoch  230/1000 Cost: 0.073335 Accuracy 100.00%
# Epoch  240/1000 Cost: 0.070798 Accuracy 100.00%
# Epoch  250/1000 Cost: 0.068434 Accuracy 100.00%
# Epoch  260/1000 Cost: 0.066228 Accuracy 100.00%
# Epoch  270/1000 Cost: 0.064162 Accuracy 100.00%
# Epoch  280/1000 Cost: 0.062225 Accuracy 100.00%
# Epoch  290/1000 Cost: 0.060403 Accuracy 100.00%
# Epoch  300/1000 Cost: 0.058688 Accuracy 100.00%
# Epoch  310/1000 Cost: 0.057070 Accuracy 100.00%
# Epoch  320/1000 Cost: 0.055540 Accuracy 100.00%
# Epoch  330/1000 Cost: 0.054092 Accuracy 100.00%
# Epoch  340/1000 Cost: 0.052720 Accuracy 100.00%
# Epoch  350/1000 Cost: 0.051416 Accuracy 100.00%
# Epoch  360/1000 Cost: 0.050177 Accuracy 100.00%
# Epoch  370/1000 Cost: 0.048998 Accuracy 100.00%
# Epoch  380/1000 Cost: 0.047873 Accuracy 100.00%
# Epoch  390/1000 Cost: 0.046800 Accuracy 100.00%
# Epoch  400/1000 Cost: 0.045775 Accuracy 100.00%
# Epoch  410/1000 Cost: 0.044795 Accuracy 100.00%
# Epoch  420/1000 Cost: 0.043857 Accuracy 100.00%
# Epoch  430/1000 Cost: 0.042958 Accuracy 100.00%
# Epoch  440/1000 Cost: 0.042095 Accuracy 100.00%
# Epoch  450/1000 Cost: 0.041268 Accuracy 100.00%
# Epoch  460/1000 Cost: 0.040472 Accuracy 100.00%
# Epoch  470/1000 Cost: 0.039708 Accuracy 100.00%
# Epoch  480/1000 Cost: 0.038972 Accuracy 100.00%
# Epoch  490/1000 Cost: 0.038263 Accuracy 100.00%
# Epoch  500/1000 Cost: 0.037580 Accuracy 100.00%
# Epoch  510/1000 Cost: 0.036921 Accuracy 100.00%
# Epoch  520/1000 Cost: 0.036286 Accuracy 100.00%
# Epoch  530/1000 Cost: 0.035672 Accuracy 100.00%
# Epoch  540/1000 Cost: 0.035079 Accuracy 100.00%
# Epoch  550/1000 Cost: 0.034505 Accuracy 100.00%
# Epoch  560/1000 Cost: 0.033951 Accuracy 100.00%
# Epoch  570/1000 Cost: 0.033414 Accuracy 100.00%
# Epoch  580/1000 Cost: 0.032894 Accuracy 100.00%
# Epoch  590/1000 Cost: 0.032390 Accuracy 100.00%
# Epoch  600/1000 Cost: 0.031902 Accuracy 100.00%
# Epoch  610/1000 Cost: 0.031428 Accuracy 100.00%
# Epoch  620/1000 Cost: 0.030968 Accuracy 100.00%
# Epoch  630/1000 Cost: 0.030522 Accuracy 100.00%
# Epoch  640/1000 Cost: 0.030089 Accuracy 100.00%
# Epoch  650/1000 Cost: 0.029667 Accuracy 100.00%
# Epoch  660/1000 Cost: 0.029258 Accuracy 100.00%
# Epoch  670/1000 Cost: 0.028860 Accuracy 100.00%
# Epoch  680/1000 Cost: 0.028473 Accuracy 100.00%
# Epoch  690/1000 Cost: 0.028096 Accuracy 100.00%
# Epoch  700/1000 Cost: 0.027729 Accuracy 100.00%
# Epoch  710/1000 Cost: 0.027371 Accuracy 100.00%
# Epoch  720/1000 Cost: 0.027023 Accuracy 100.00%
# Epoch  730/1000 Cost: 0.026684 Accuracy 100.00%
# Epoch  740/1000 Cost: 0.026353 Accuracy 100.00%
# Epoch  750/1000 Cost: 0.026030 Accuracy 100.00%
# Epoch  760/1000 Cost: 0.025715 Accuracy 100.00%
# Epoch  770/1000 Cost: 0.025408 Accuracy 100.00%
# Epoch  780/1000 Cost: 0.025108 Accuracy 100.00%
# Epoch  790/1000 Cost: 0.024815 Accuracy 100.00%
# Epoch  800/1000 Cost: 0.024529 Accuracy 100.00%
# Epoch  810/1000 Cost: 0.024250 Accuracy 100.00%
# Epoch  820/1000 Cost: 0.023977 Accuracy 100.00%
# Epoch  830/1000 Cost: 0.023710 Accuracy 100.00%
# Epoch  840/1000 Cost: 0.023449 Accuracy 100.00%
# Epoch  850/1000 Cost: 0.023193 Accuracy 100.00%
# Epoch  860/1000 Cost: 0.022944 Accuracy 100.00%
# Epoch  870/1000 Cost: 0.022699 Accuracy 100.00%
# Epoch  880/1000 Cost: 0.022460 Accuracy 100.00%
# Epoch  890/1000 Cost: 0.022226 Accuracy 100.00%
# Epoch  900/1000 Cost: 0.021997 Accuracy 100.00%
# Epoch  910/1000 Cost: 0.021772 Accuracy 100.00%
# Epoch  920/1000 Cost: 0.021552 Accuracy 100.00%
# Epoch  930/1000 Cost: 0.021336 Accuracy 100.00%
# Epoch  940/1000 Cost: 0.021125 Accuracy 100.00%
# Epoch  950/1000 Cost: 0.020918 Accuracy 100.00%
# Epoch  960/1000 Cost: 0.020715 Accuracy 100.00%
# Epoch  970/1000 Cost: 0.020516 Accuracy 100.00%
# Epoch  980/1000 Cost: 0.020321 Accuracy 100.00%
# Epoch  990/1000 Cost: 0.020129 Accuracy 100.00%
# Epoch 1000/1000 Cost: 0.019941 Accuracy 100.00%
