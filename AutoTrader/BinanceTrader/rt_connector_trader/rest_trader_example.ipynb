# %%
import time
import logging
from binance.lib.utils import config_logging
from binance.websocket.um_futures.websocket_client import UMFuturesWebsocketClient
from binance.um_futures import UMFutures
from binance.error import ClientError

import matplotlib.pyplot as plt
import seaborn as sns

from cert import binanceKey
from cert import test_binanceKey
from cert.myfuncs import *


# import API KEY and SECRET KEY
## realnet (base_url is realnet default)
API_KEY = binanceKey.API_KEY
SECRET_KEY = binanceKey.SECRET_KEY
## testnet
key = test_binanceKey.API_KEY
secret = test_binanceKey.SECRET_KEY
## testnet base_urls (for test trading, stream_url = futures_websocket_testnet and base_url = futures_testnet)
futures_testnet = test_binanceKey.futures_testnet
futures_websocket_testnet = test_binanceKey.futures_websocket_testnet
# END


# defining futures client
um_futures_real = UMFutures(key=API_KEY, secret=SECRET_KEY)
um_futures_client = UMFutures(key=key, secret=secret, base_url=futures_testnet) # testnet
my_client = UMFuturesWebsocketClient(stream_url=futures_websocket_testnet) # testnet
# END

# %%
config_logging(logging, logging.DEBUG)

try:
    side = "BUY"
    quantity = 0.05
    price = 23180.0
    response = um_futures_client.new_order_test(
        symbol="BTCUSDT",
        side=side,
        type="LIMIT",
        quantity=quantity,
        timeInForce="GTC",
        price=price
    )
    logging.info(response)
except ClientError as error:
    logging.error(
        "Found error. status: {}, error code: {}, error message: {}".format(
            error.status_code, error.error_code, error.error_message
        )
    )
# Out:
# DEBUG:root:url: https://testnet.binancefuture.com/fapi/v1/order/test
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): testnet.binancefuture.com:443
# DEBUG:urllib3.connectionpool:https://testnet.binancefuture.com:443 "POST /fapi/v1/order/test?symbol=BTCUSDT&side=BUY&type=LIMIT&quantity=0.05&timeInForce=GTC&price=23180.0&timestamp=1675097186821&signature=4985d5cc32726c33b29baf62942acb7a07f4aa58507c3ebdf0045109a07359d4 HTTP/1.1" 200 None
# DEBUG:root:raw response from server:{"orderId":null,"symbol":"null","status":"null","clientOrderId":"null","price":"null","avgPrice":"null","origQty":"null","executedQty":"null","cumQuote":"null","timeInForce":"null","type":"null","reduceOnly":null,"closePosition":null,"side":"null","positionSide":"null","stopPrice":"null","workingType":"null","priceProtect":null,"origType":"null","updateTime":null}
# INFO:root:{'orderId': None, 'symbol': 'null', 'status': 'null', 'clientOrderId': 'null', 'price': 'null', 'avgPrice': 'null', 'origQty': 'null', 'executedQty': 'null', 'cumQuote': 'null', 'timeInForce': 'null', 'type': 'null', 'reduceOnly': None, 'closePosition': None, 'side': 'null', 'positionSide': 'null', 'stopPrice': 'null', 'workingType': 'null', 'priceProtect': None, 'origType': 'null', 'updateTime': None}

# %%
config_logging(logging, logging.DEBUG)

try:
    response = um_futures_client.new_order(
        symbol="BTCUSDT",
        side="BUY",
        type="MARKET",
        quantity=0.01,
    )
    logging.info(response)
except ClientError as error:
    logging.error(
        "Found error. status: {}, error code: {}, error message: {}".format(
            error.status_code, error.error_code, error.error_message
        )
    )
# Out:
# DEBUG:root:url: https://testnet.binancefuture.com/fapi/v1/order
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): testnet.binancefuture.com:443
# DEBUG:urllib3.connectionpool:https://testnet.binancefuture.com:443 "POST /fapi/v1/order?symbol=BTCUSDT&side=BUY&type=MARKET&quantity=0.01&timestamp=1675097836582&signature=f41c9b254bf9b8ee6a983630837a2a3c5774b96eb36c9bcc1dceb9a1faf3f486 HTTP/1.1" 200 None
# DEBUG:root:raw response from server:{"orderId":3279396289,"symbol":"BTCUSDT","status":"NEW","clientOrderId":"i8ThrSZllLxCFYYUrWYoLV","price":"0","avgPrice":"0.00000","origQty":"0.010","executedQty":"0","cumQty":"0","cumQuote":"0","timeInForce":"GTC","type":"MARKET","reduceOnly":false,"closePosition":false,"side":"BUY","positionSide":"BOTH","stopPrice":"0","workingType":"CONTRACT_PRICE","priceProtect":false,"origType":"MARKET","updateTime":1675097838371}
# INFO:root:{'orderId': 3279396289, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'i8ThrSZllLxCFYYUrWYoLV', 'price': '0', 'avgPrice': '0.00000', 'origQty': '0.010', 'executedQty': '0', 'cumQty': '0', 'cumQuote': '0', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'BOTH', 'stopPrice': '0', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'updateTime': 1675097838371}

# %%
um_futures_client.get_account_trades("BTCUSDT")
# Out:
# DEBUG:root:url: https://testnet.binancefuture.com/fapi/v1/userTrades
# DEBUG:urllib3.connectionpool:https://testnet.binancefuture.com:443 "GET /fapi/v1/userTrades?symbol=BTCUSDT&timestamp=1675097584567&signature=9db2bb11fa8170ac299629571c7df4418e125c113d206793adc7aec1b4eb5715 HTTP/1.1" 200 None
# DEBUG:root:raw response from server:[{"symbol":"BTCUSDT","id":248983941,"orderId":3278956313,"side":"BUY","price":"22960","qty":"0.003","realizedPnl":"0","marginAsset":"USDT","quoteQty":"68.88000","commission":"0.02755200","commissionAsset":"USDT","time":1674915578824,"positionSide":"BOTH","buyer":true,"maker":false},{"symbol":"BTCUSDT","id":248983942,"orderId":3278956313,"side":"BUY","price":"22968.80","qty":"0.007","realizedPnl":"0","marginAsset":"USDT","quoteQty":"160.78160","commission":"0.06431264","commissionAsset":"USDT","time":1674915578824,"positionSide":"BOTH","buyer":true,"maker":false},{"symbol":"BTCUSDT","id":248983988,"orderId":3278956505,"side":"SELL","price":"22960.20","qty":"0.010","realizedPnl":"-0.05959999","marginAsset":"USDT","quoteQty":"229.60200","commission":"0.09184080","commissionAsset":"USDT","time":1674915692668,"positionSide":"BOTH","buyer":false,"maker":false},{"symbol":"BTCUSDT","id":248984417,"orderId":3278957965,"side":"BUY","price":"22975.60","qty":"1","realizedPnl":"0","marginAsset":"USDT","quoteQty":"22975.60000","commission":"4.59511999","commissionAsset":"USDT","time":1674916536262,"positionSide":"BOTH","buyer":true,"maker":true},{"symbol":"BTCUSDT","id":248984464,"orderId":3278958165,"side":"SELL","price":"22969","qty":"1","realizedPnl":"-6.59999999","marginAsset":"USDT","quoteQty":"22969","commission":"9.18760000","commissionAsset":"USDT","time":1674916674004,"positionSide":"BOTH","buyer":false,"maker":false},{"symbol":"BTCUSDT","id":248984468,"orderId":3278958180,"side":"SELL","price":"22969","qty":"1","realizedPnl":"0","marginAsset":"USDT","quoteQty":"22969","commission":"9.18760000","commissionAsset":"USDT","time":1674916687330,"positionSide":"BOTH","buyer":false,"maker":false},{"symbol":"BTCUSDT","id":248984482,"orderId":3278958225,"side":"BUY","price":"22972.30","qty":"0.755","realizedPnl":"-2.49150000","marginAsset":"USDT","quoteQty":"17344.08650","commission":"6.93763460","commissionAsset":"USDT","time":1674916724082,"positionSide":"BOTH","buyer":true,"maker":false},{"symbol":"BTCUSDT","id":248984483,"orderId":3278958225,"side":"BUY","price":"22973","qty":"0.345","realizedPnl":"-0.98000000","marginAsset":"USDT","quoteQty":"7925.68500","commission":"3.17027400","commissionAsset":"USDT","time":1674916724082,"positionSide":"BOTH","buyer":true,"maker":false},{"symbol":"BTCUSDT","id":248984489,"orderId":3278958248,"side":"SELL","price":"22964.40","qty":"0.100","realizedPnl":"-0.86000000","marginAsset":"USDT","quoteQty":"2296.44000","commission":"0.91857600","commissionAsset":"USDT","time":1674916743424,"positionSide":"BOTH","buyer":false,"maker":false},{"symbol":"BTCUSDT","id":248984574,"orderId":3278958551,"side":"BUY","price":"22967.50","qty":"1","realizedPnl":"0","marginAsset":"USDT","quoteQty":"22967.50000","commission":"9.18699999","commissionAsset":"USDT","time":1674916966036,"positionSide":"BOTH","buyer":true,"maker":false},{"symbol":"BTCUSDT","id":248984596,"orderId":3278958652,"side":"SELL","price":"22966.10","qty":"1","realizedPnl":"-1.39999999","marginAsset":"USDT","quoteQty":"22966.10000","commission":"9.18643999","commissionAsset":"USDT","time":1674917008249,"positionSide":"BOTH","buyer":false,"maker":false},{"symbol":"BTCUSDT","id":248985340,"orderId":3278961275,"side":"BUY","price":"22971.90","qty":"0.500","realizedPnl":"0","marginAsset":"USDT","quoteQty":"11485.95000","commission":"4.59438000","commissionAsset":"USDT","time":1674918515844,"positionSide":"BOTH","buyer":true,"maker":false},{"symbol":"BTCUSDT","id":248985408,"orderId":3278961432,"side":"SELL","price":"22984.50","qty":"0.600","realizedPnl":"6.29999999","marginAsset":"USDT","quoteQty":"13790.70000","commission":"5.51628000","commissionAsset":"USDT","time":1674918586049,"positionSide":"BOTH","buyer":false,"maker":false},{"symbol":"BTCUSDT","id":248985420,"orderId":3278961480,"side":"BUY","price":"22987","qty":"0.100","realizedPnl":"-0.25000000","marginAsset":"USDT","quoteQty":"2298.70000","commission":"0.9194 ...
# [{'symbol': 'BTCUSDT',
#   'id': 248983941,
#   'orderId': 3278956313,
#   'side': 'BUY',
#   'price': '22960',
#   'qty': '0.003',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '68.88000',
#   'commission': '0.02755200',
#   'commissionAsset': 'USDT',
#   'time': 1674915578824,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248983942,
#   'orderId': 3278956313,
#   'side': 'BUY',
#   'price': '22968.80',
#   'qty': '0.007',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '160.78160',
#   'commission': '0.06431264',
#   'commissionAsset': 'USDT',
#   'time': 1674915578824,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248983988,
#   'orderId': 3278956505,
#   'side': 'SELL',
#   'price': '22960.20',
#   'qty': '0.010',
#   'realizedPnl': '-0.05959999',
#   'marginAsset': 'USDT',
#   'quoteQty': '229.60200',
#   'commission': '0.09184080',
#   'commissionAsset': 'USDT',
#   'time': 1674915692668,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248984417,
#   'orderId': 3278957965,
#   'side': 'BUY',
#   'price': '22975.60',
#   'qty': '1',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '22975.60000',
#   'commission': '4.59511999',
#   'commissionAsset': 'USDT',
#   'time': 1674916536262,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'BTCUSDT',
#   'id': 248984464,
#   'orderId': 3278958165,
#   'side': 'SELL',
#   'price': '22969',
#   'qty': '1',
#   'realizedPnl': '-6.59999999',
#   'marginAsset': 'USDT',
#   'quoteQty': '22969',
#   'commission': '9.18760000',
#   'commissionAsset': 'USDT',
#   'time': 1674916674004,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248984468,
#   'orderId': 3278958180,
#   'side': 'SELL',
#   'price': '22969',
#   'qty': '1',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '22969',
#   'commission': '9.18760000',
#   'commissionAsset': 'USDT',
#   'time': 1674916687330,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248984482,
#   'orderId': 3278958225,
#   'side': 'BUY',
#   'price': '22972.30',
#   'qty': '0.755',
#   'realizedPnl': '-2.49150000',
#   'marginAsset': 'USDT',
#   'quoteQty': '17344.08650',
#   'commission': '6.93763460',
#   'commissionAsset': 'USDT',
#   'time': 1674916724082,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248984483,
#   'orderId': 3278958225,
#   'side': 'BUY',
#   'price': '22973',
#   'qty': '0.345',
#   'realizedPnl': '-0.98000000',
#   'marginAsset': 'USDT',
#   'quoteQty': '7925.68500',
#   'commission': '3.17027400',
#   'commissionAsset': 'USDT',
#   'time': 1674916724082,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248984489,
#   'orderId': 3278958248,
#   'side': 'SELL',
#   'price': '22964.40',
#   'qty': '0.100',
#   'realizedPnl': '-0.86000000',
#   'marginAsset': 'USDT',
#   'quoteQty': '2296.44000',
#   'commission': '0.91857600',
#   'commissionAsset': 'USDT',
#   'time': 1674916743424,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248984574,
#   'orderId': 3278958551,
#   'side': 'BUY',
#   'price': '22967.50',
#   'qty': '1',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '22967.50000',
#   'commission': '9.18699999',
#   'commissionAsset': 'USDT',
#   'time': 1674916966036,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248984596,
#   'orderId': 3278958652,
#   'side': 'SELL',
#   'price': '22966.10',
#   'qty': '1',
#   'realizedPnl': '-1.39999999',
#   'marginAsset': 'USDT',
#   'quoteQty': '22966.10000',
#   'commission': '9.18643999',
#   'commissionAsset': 'USDT',
#   'time': 1674917008249,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248985340,
#   'orderId': 3278961275,
#   'side': 'BUY',
#   'price': '22971.90',
#   'qty': '0.500',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '11485.95000',
#   'commission': '4.59438000',
#   'commissionAsset': 'USDT',
#   'time': 1674918515844,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248985408,
#   'orderId': 3278961432,
#   'side': 'SELL',
#   'price': '22984.50',
#   'qty': '0.600',
#   'realizedPnl': '6.29999999',
#   'marginAsset': 'USDT',
#   'quoteQty': '13790.70000',
#   'commission': '5.51628000',
#   'commissionAsset': 'USDT',
#   'time': 1674918586049,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248985420,
#   'orderId': 3278961480,
#   'side': 'BUY',
#   'price': '22987',
#   'qty': '0.100',
#   'realizedPnl': '-0.25000000',
#   'marginAsset': 'USDT',
#   'quoteQty': '2298.70000',
#   'commission': '0.91948000',
#   'commissionAsset': 'USDT',
#   'time': 1674918607705,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248986904,
#   'orderId': 3278966929,
#   'side': 'BUY',
#   'price': '23024.70',
#   'qty': '0.100',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '2302.47000',
#   'commission': '0.92098800',
#   'commissionAsset': 'USDT',
#   'time': 1674921193244,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248986970,
#   'orderId': 3278967236,
#   'side': 'SELL',
#   'price': '23008.90',
#   'qty': '0.100',
#   'realizedPnl': '-1.58000000',
#   'marginAsset': 'USDT',
#   'quoteQty': '2300.89000',
#   'commission': '0.92035600',
#   'commissionAsset': 'USDT',
#   'time': 1674921357216,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248986979,
#   'orderId': 3278967274,
#   'side': 'BUY',
#   'price': '23012.10',
#   'qty': '0.001',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '23.01210',
#   'commission': '0.00920484',
#   'commissionAsset': 'USDT',
#   'time': 1674921369613,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248986980,
#   'orderId': 3278967274,
#   'side': 'BUY',
#   'price': '23026.10',
#   'qty': '0.001',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '23.02610',
#   'commission': '0.00921044',
#   'commissionAsset': 'USDT',
#   'time': 1674921369613,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248986981,
#   'orderId': 3278967274,
#   'side': 'BUY',
#   'price': '23026.40',
#   'qty': '0.098',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '2256.58720',
#   'commission': '0.90263488',
#   'commissionAsset': 'USDT',
#   'time': 1674921369613,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248986993,
#   'orderId': 3278967325,
#   'side': 'SELL',
#   'price': '23011.10',
#   'qty': '0.001',
#   'realizedPnl': '-0.01515400',
#   'marginAsset': 'USDT',
#   'quoteQty': '23.01110',
#   'commission': '0.00920444',
#   'commissionAsset': 'USDT',
#   'time': 1674921393108,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248986994,
#   'orderId': 3278967325,
#   'side': 'SELL',
#   'price': '23008.90',
#   'qty': '0.099',
#   'realizedPnl': '-1.71804600',
#   'marginAsset': 'USDT',
#   'quoteQty': '2277.88110',
#   'commission': '0.91115244',
#   'commissionAsset': 'USDT',
#   'time': 1674921393108,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248987004,
#   'orderId': 3278967386,
#   'side': 'BUY',
#   'price': '23026.10',
#   'qty': '0.001',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '23.02610',
#   'commission': '0.00921044',
#   'commissionAsset': 'USDT',
#   'time': 1674921418659,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248987005,
#   'orderId': 3278967386,
#   'side': 'BUY',
#   'price': '23026.40',
#   'qty': '0.099',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '2279.61360',
#   'commission': '0.91184544',
#   'commissionAsset': 'USDT',
#   'time': 1674921418659,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 248987024,
#   'orderId': 3278967422,
#   'side': 'SELL',
#   'price': '23024.90',
#   'qty': '0.100',
#   'realizedPnl': '-0.14969999',
#   'marginAsset': 'USDT',
#   'quoteQty': '2302.49000',
#   'commission': '0.92099600',
#   'commissionAsset': 'USDT',
#   'time': 1674921431773,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 249011861,
#   'orderId': 3279093726,
#   'side': 'SELL',
#   'price': '23416.90',
#   'qty': '0.100',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '2341.69000',
#   'commission': '0.93667600',
#   'commissionAsset': 'USDT',
#   'time': 1674987989188,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 249011866,
#   'orderId': 3279093772,
#   'side': 'BUY',
#   'price': '23427.90',
#   'qty': '0.100',
#   'realizedPnl': '-1.10000000',
#   'marginAsset': 'USDT',
#   'quoteQty': '2342.79000',
#   'commission': '0.93711600',
#   'commissionAsset': 'USDT',
#   'time': 1674988004003,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 249112025,
#   'orderId': 3279389138,
#   'side': 'BUY',
#   'price': '23188.70',
#   'qty': '0.001',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '23.18870',
#   'commission': '0.00927547',
#   'commissionAsset': 'USDT',
#   'time': 1675096485957,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 249112026,
#   'orderId': 3279389138,
#   'side': 'BUY',
#   'price': '23188.80',
#   'qty': '0.049',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '1136.25120',
#   'commission': '0.45450048',
#   'commissionAsset': 'USDT',
#   'time': 1675096485957,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 249112042,
#   'orderId': 3279389177,
#   'side': 'SELL',
#   'price': '23188.40',
#   'qty': '0.002',
#   'realizedPnl': '-0.00079599',
#   'marginAsset': 'USDT',
#   'quoteQty': '46.37680',
#   'commission': '0.01855072',
#   'commissionAsset': 'USDT',
#   'time': 1675096495602,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 249112043,
#   'orderId': 3279389177,
#   'side': 'SELL',
#   'price': '23188.30',
#   'qty': '0.002',
#   'realizedPnl': '-0.00099600',
#   'marginAsset': 'USDT',
#   'quoteQty': '46.37660',
#   'commission': '0.01855064',
#   'commissionAsset': 'USDT',
#   'time': 1675096495602,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 249112044,
#   'orderId': 3279389177,
#   'side': 'SELL',
#   'price': '23188.20',
#   'qty': '0.002',
#   'realizedPnl': '-0.00119599',
#   'marginAsset': 'USDT',
#   'quoteQty': '46.37640',
#   'commission': '0.01855056',
#   'commissionAsset': 'USDT',
#   'time': 1675096495602,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 249112045,
#   'orderId': 3279389177,
#   'side': 'SELL',
#   'price': '23188.10',
#   'qty': '0.002',
#   'realizedPnl': '-0.00139599',
#   'marginAsset': 'USDT',
#   'quoteQty': '46.37620',
#   'commission': '0.01855048',
#   'commissionAsset': 'USDT',
#   'time': 1675096495602,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 249112046,
#   'orderId': 3279389177,
#   'side': 'SELL',
#   'price': '23188',
#   'qty': '0.042',
#   'realizedPnl': '-0.03351599',
#   'marginAsset': 'USDT',
#   'quoteQty': '973.89600',
#   'commission': '0.38955840',
#   'commissionAsset': 'USDT',
#   'time': 1675096495603,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 249113286,
#   'orderId': 3279392133,
#   'side': 'BUY',
#   'price': '23165.90',
#   'qty': '0.050',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '1158.29500',
#   'commission': '0.46331800',
#   'commissionAsset': 'USDT',
#   'time': 1675097066805,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 249113303,
#   'orderId': 3279392173,
#   'side': 'SELL',
#   'price': '23162.20',
#   'qty': '0.002',
#   'realizedPnl': '-0.00739999',
#   'marginAsset': 'USDT',
#   'quoteQty': '46.32440',
#   'commission': '0.01852976',
#   'commissionAsset': 'USDT',
#   'time': 1675097074954,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 249113304,
#   'orderId': 3279392173,
#   'side': 'SELL',
#   'price': '23162.10',
#   'qty': '0.002',
#   'realizedPnl': '-0.00759999',
#   'marginAsset': 'USDT',
#   'quoteQty': '46.32420',
#   'commission': '0.01852968',
#   'commissionAsset': 'USDT',
#   'time': 1675097074955,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 249113305,
#   'orderId': 3279392173,
#   'side': 'SELL',
#   'price': '23162',
#   'qty': '0.046',
#   'realizedPnl': '-0.17940000',
#   'marginAsset': 'USDT',
#   'quoteQty': '1065.45200',
#   'commission': '0.42618080',
#   'commissionAsset': 'USDT',
#   'time': 1675097074955,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False}]

# %%
from cert.myfuncs import *
ms2dt(1675097074955)
# Out:
# datetime.datetime(2023, 1, 31, 1, 44, 34)

# %%
import time
import logging
from binance.lib.utils import config_logging
from binance.um_futures import UMFutures
from binance.websocket.um_futures.websocket_client import UMFuturesWebsocketClient

config_logging(logging, logging.DEBUG)


def message_handler(message):
    print(message)

response = um_futures_client.new_listen_key()

logging.info("Listen key : {}".format(response["listenKey"]))

my_client.start()

my_client.user_data(
    listen_key=response["listenKey"],
    id=1,
    callback=message_handler,
)

time.sleep(30)

logging.debug("closing ws connection")
my_client.stop()
# Out:
# DEBUG:root:url: https://testnet.binancefuture.com/fapi/v1/listenKey
# DEBUG:urllib3.connectionpool:https://testnet.binancefuture.com:443 "POST /fapi/v1/listenKey HTTP/1.1" 200 None
# DEBUG:root:raw response from server:{"listenKey":"NICxZRw7Ipkl0Y4SMYqJE1EREsxeooz1WXktgkqSeFyeyZhCkLuMT486kY0z1ywC"}
# INFO:root:Listen key : NICxZRw7Ipkl0Y4SMYqJE1EREsxeooz1WXktgkqSeFyeyZhCkLuMT486kY0z1ywC
# INFO:root:Connection with URL: wss://stream.binancefuture.com/ws
# INFO:root:Start to connect....
# INFO:root:Server connected
# INFO:root:Sending message to Server: b'{"method": "SUBSCRIBE", "params": ["NICxZRw7Ipkl0Y4SMYqJE1EREsxeooz1WXktgkqSeFyeyZhCkLuMT486kY0z1ywC"], "id": 1}'
# {'id': 1, 'result': None}
# {'e': 'ORDER_TRADE_UPDATE', 'T': 1675097066805, 'E': 1675097066806, 'o': {'s': 'BTCUSDT', 'c': 'web_HJrCzn28ffvwB6UfbvmC', 'S': 'BUY', 'o': 'LIMIT', 'f': 'GTC', 'q': '0.050', 'p': '23183.80', 'ap': '0', 'sp': '0', 'x': 'NEW', 'X': 'NEW', 'i': 3279392133, 'l': '0', 'z': '0', 'L': '0', 'n': '0', 'N': 'USDT', 'T': 1675097066805, 't': 0, 'b': '1159.19000', 'a': '0', 'm': False, 'R': False, 'wt': 'CONTRACT_PRICE', 'ot': 'LIMIT', 'ps': 'BOTH', 'cp': False, 'rp': '0', 'pP': False, 'si': 0, 'ss': 0}}
# {'e': 'ACCOUNT_UPDATE', 'T': 1675097066805, 'E': 1675097066807, 'a': {'B': [{'a': 'USDT', 'wb': '14916.68456039', 'cw': '14916.68456039', 'bc': '0'}], 'P': [{'s': 'BTCUSDT', 'pa': '0.050', 'ep': '23165.90000', 'cr': '-10.94189993', 'up': '1158.25262442', 'mt': 'cross', 'iw': '0', 'ps': 'BOTH', 'ma': 'USDT'}], 'm': 'ORDER'}}
# {'e': 'ORDER_TRADE_UPDATE', 'T': 1675097066805, 'E': 1675097066808, 'o': {'s': 'BTCUSDT', 'c': 'web_HJrCzn28ffvwB6UfbvmC', 'S': 'BUY', 'o': 'LIMIT', 'f': 'GTC', 'q': '0.050', 'p': '23183.80', 'ap': '23165.90000', 'sp': '0', 'x': 'TRADE', 'X': 'FILLED', 'i': 3279392133, 'l': '0.050', 'z': '0.050', 'L': '23165.90', 'n': '0.46331800', 'N': 'USDT', 'T': 1675097066805, 't': 249113286, 'b': '0', 'a': '0', 'm': False, 'R': False, 'wt': 'CONTRACT_PRICE', 'ot': 'LIMIT', 'ps': 'BOTH', 'cp': False, 'rp': '0', 'pP': False, 'si': 0, 'ss': 0}}
# {'e': 'ORDER_TRADE_UPDATE', 'T': 1675097074954, 'E': 1675097074955, 'o': {'s': 'BTCUSDT', 'c': 'web_LkbYCYhc9eO8eNcn01qt', 'S': 'SELL', 'o': 'MARKET', 'f': 'GTC', 'q': '0.050', 'p': '0', 'ap': '0', 'sp': '0', 'x': 'NEW', 'X': 'NEW', 'i': 3279392173, 'l': '0', 'z': '0', 'L': '0', 'n': '0', 'N': 'USDT', 'T': 1675097074954, 't': 0, 'b': '0', 'a': '0', 'm': False, 'R': True, 'wt': 'CONTRACT_PRICE', 'ot': 'MARKET', 'ps': 'BOTH', 'cp': False, 'rp': '0', 'pP': False, 'si': 0, 'ss': 0}}
# {'e': 'ACCOUNT_UPDATE', 'T': 1675097074954, 'E': 1675097074957, 'a': {'B': [{'a': 'USDT', 'wb': '14916.65863064', 'cw': '14916.65863064', 'bc': '0'}], 'P': [{'s': 'BTCUSDT', 'pa': '0.048', 'ep': '23165.90000', 'cr': '-10.94929992', 'up': '1111.96773973', 'mt': 'cross', 'iw': '0', 'ps': 'BOTH', 'ma': 'USDT'}], 'm': 'ORDER'}}
# {'e': 'ORDER_TRADE_UPDATE', 'T': 1675097074954, 'E': 1675097074958, 'o': {'s': 'BTCUSDT', 'c': 'web_LkbYCYhc9eO8eNcn01qt', 'S': 'SELL', 'o': 'MARKET', 'f': 'GTC', 'q': '0.050', 'p': '0', 'ap': '23162.20000', 'sp': '0', 'x': 'TRADE', 'X': 'PARTIALLY_FILLED', 'i': 3279392173, 'l': '0.002', 'z': '0.002', 'L': '23162.20', 'n': '0.01852976', 'N': 'USDT', 'T': 1675097074954, 't': 249113303, 'b': '0', 'a': '0', 'm': False, 'R': True, 'wt': 'CONTRACT_PRICE', 'ot': 'MARKET', 'ps': 'BOTH', 'cp': False, 'rp': '-0.00739999', 'pP': False, 'si': 0, 'ss': 0}}
# {'e': 'ACCOUNT_UPDATE', 'T': 1675097074955, 'E': 1675097074959, 'a': {'B': [{'a': 'USDT', 'wb': '14916.63250097', 'cw': '14916.63250097', 'bc': '0'}], 'P': [{'s': 'BTCUSDT', 'pa': '0.046', 'ep': '23165.90000', 'cr': '-10.95689991', 'up': '1065.63575057', 'mt': 'cross', 'iw': '0', 'ps': 'BOTH', 'ma': 'USDT'}], 'm': 'ORDER'}}
# {'e': 'ORDER_TRADE_UPDATE', 'T': 1675097074955, 'E': 1675097074959, 'o': {'s': 'BTCUSDT', 'c': 'web_LkbYCYhc9eO8eNcn01qt', 'S': 'SELL', 'o': 'MARKET', 'f': 'GTC', 'q': '0.050', 'p': '0', 'ap': '23162.15000', 'sp': '0', 'x': 'TRADE', 'X': 'PARTIALLY_FILLED', 'i': 3279392173, 'l': '0.002', 'z': '0.004', 'L': '23162.10', 'n': '0.01852968', 'N': 'USDT', 'T': 1675097074955, 't': 249113304, 'b': '0', 'a': '0', 'm': False, 'R': True, 'wt': 'CONTRACT_PRICE', 'ot': 'MARKET', 'ps': 'BOTH', 'cp': False, 'rp': '-0.00759999', 'pP': False, 'si': 0, 'ss': 0}}
# {'e': 'ACCOUNT_UPDATE', 'T': 1675097074955, 'E': 1675097074960, 'a': {'B': [{'a': 'USDT', 'wb': '14916.02692017', 'cw': '14916.02692017', 'bc': '0'}], 'P': [{'s': 'BTCUSDT', 'pa': '0', 'ep': '0.00000', 'cr': '-11.13629991', 'up': '0', 'mt': 'cross', 'iw': '0', 'ps': 'BOTH', 'ma': 'USDT'}], 'm': 'ORDER'}}
# {'e': 'ORDER_TRADE_UPDATE', 'T': 1675097074955, 'E': 1675097074960, 'o': {'s': 'BTCUSDT', 'c': 'web_LkbYCYhc9eO8eNcn01qt', 'S': 'SELL', 'o': 'MARKET', 'f': 'GTC', 'q': '0.050', 'p': '0', 'ap': '23162.01200', 'sp': '0', 'x': 'TRADE', 'X': 'FILLED', 'i': 3279392173, 'l': '0.046', 'z': '0.050', 'L': '23162', 'n': '0.42618080', 'N': 'USDT', 'T': 1675097074955, 't': 249113305, 'b': '0', 'a': '0', 'm': False, 'R': True, 'wt': 'CONTRACT_PRICE', 'ot': 'MARKET', 'ps': 'BOTH', 'cp': False, 'rp': '-0.17940000', 'pP': False, 'si': 0, 'ss': 0}}
# {'e': 'ORDER_TRADE_UPDATE', 'T': 1675097081119, 'E': 1675097081120, 'o': {'s': 'BTCUSDT', 'c': 'web_abKJPW2HC800lZqQwPzC', 'S': 'SELL', 'o': 'LIMIT', 'f': 'GTC', 'q': '0.050', 'p': '23165.90', 'ap': '0', 'sp': '0', 'x': 'NEW', 'X': 'NEW', 'i': 3279392190, 'l': '0', 'z': '0', 'L': '0', 'n': '0', 'N': 'USDT', 'T': 1675097081119, 't': 0, 'b': '0', 'a': '1158.31712', 'm': False, 'R': False, 'wt': 'CONTRACT_PRICE', 'ot': 'LIMIT', 'ps': 'BOTH', 'cp': False, 'rp': '0', 'pP': False, 'si': 0, 'ss': 0}}
# {'e': 'ORDER_TRADE_UPDATE', 'T': 1675097086100, 'E': 1675097086101, 'o': {'s': 'BTCUSDT', 'c': 'web_abKJPW2HC800lZqQwPzC', 'S': 'SELL', 'o': 'LIMIT', 'f': 'GTC', 'q': '0.050', 'p': '23165.90', 'ap': '0', 'sp': '0', 'x': 'CANCELED', 'X': 'CANCELED', 'i': 3279392190, 'l': '0', 'z': '0', 'L': '0', 'n': '0', 'N': 'USDT', 'T': 1675097086100, 't': 0, 'b': '0', 'a': '0', 'm': False, 'R': False, 'wt': 'CONTRACT_PRICE', 'ot': 'LIMIT', 'ps': 'BOTH', 'cp': False, 'rp': '0', 'pP': False, 'si': 0, 'ss': 0}}
# DEBUG:root:closing ws connection
# WARNING:root:WebSocket connection closed: connection was closed uncleanly ("peer dropped the TCP connection without previous WebSocket closing handshake"), code: 1006, clean: False, reason: connection was closed uncleanly ("peer dropped the TCP connection without previous WebSocket closing handshake")

# %%
config_logging(logging, logging.DEBUG)

try:
    response = um_futures_real.new_order_test(
        symbol="BTCUSDT",
        side="BUY",
        type="LIMIT",
        quantity=0.001,
        timeInForce="GTC",
        price=23150.0,
    )
    logging.info(response)
except ClientError as error:
    logging.error(
        "Found error. status: {}, error code: {}, error message: {}".format(
            error.status_code, error.error_code, error.error_message
        )
    )
# Out:
# DEBUG:root:url: https://fapi.binance.com/fapi/v1/order/test
# DEBUG:urllib3.connectionpool:https://fapi.binance.com:443 "POST /fapi/v1/order/test?symbol=BTCUSDT&side=BUY&type=LIMIT&quantity=0.001&timeInForce=GTC&price=23150.0&timestamp=1675097813402&signature=5752b96e4594c7252f8ca3f0aa1bcc21944a3248857544baa78c22e55de13ebe HTTP/1.1" 200 None
# DEBUG:root:raw response from server:{"orderId":null,"symbol":"null","status":"null","clientOrderId":"null","price":"null","avgPrice":"null","origQty":"null","executedQty":"null","cumQuote":"null","timeInForce":"null","type":"null","reduceOnly":null,"closePosition":null,"side":"null","positionSide":"null","stopPrice":"null","workingType":"null","priceProtect":null,"origType":"null","updateTime":null}
# INFO:root:{'orderId': None, 'symbol': 'null', 'status': 'null', 'clientOrderId': 'null', 'price': 'null', 'avgPrice': 'null', 'origQty': 'null', 'executedQty': 'null', 'cumQuote': 'null', 'timeInForce': 'null', 'type': 'null', 'reduceOnly': None, 'closePosition': None, 'side': 'null', 'positionSide': 'null', 'stopPrice': 'null', 'workingType': 'null', 'priceProtect': None, 'origType': 'null', 'updateTime': None}
