# %%
import time
import logging
from binance.lib.utils import config_logging
from binance.websocket.um_futures.websocket_client import UMFuturesWebsocketClient
from binance.um_futures import UMFutures
from binance.error import ClientError

import matplotlib.pyplot as plt
import seaborn as sns

from cert import binanceKey
from cert import test_binanceKey
from cert.myfuncs import *


# import API KEY and SECRET KEY
## realnet (base_url is realnet default)
API_KEY = binanceKey.API_KEY
SECRET_KEY = binanceKey.SECRET_KEY
## testnet
key = test_binanceKey.API_KEY
secret = test_binanceKey.SECRET_KEY
## testnet base_urls (for test trading, stream_url = futures_websocket_testnet and base_url = futures_testnet)
futures_testnet = test_binanceKey.futures_testnet
futures_websocket_testnet = test_binanceKey.futures_websocket_testnet
# END


# defining futures client
um_futures_client = UMFutures(key=key, secret=secret, base_url=futures_testnet) # testnet
my_client = UMFuturesWebsocketClient(stream_url=futures_websocket_testnet) # testnet
# END

# %%
from trade_rules.trade_prelim import DataPrelim
predata = DataPrelim(um_futures_client)

listenKey = predata.new_listenKey()
asset_USDT, position_BTCUSDT = predata.get_account()
current_asset = float(asset_USDT['walletBalance'])
current_amt, entryPrice = float(position_BTCUSDT['positionAmt']), float(position_BTCUSDT['entryPrice'])

# %%
# defining websocket streams
## parameters.
SYMBOL = "btcusdt"
p_aggTrade = dict()
p_markPrice = dict(
    speed=1,
)
p_kline = dict(
    interval='2h'
)
## make each streams
aggTrade_stream = f"{SYMBOL}@aggTrade"
markPrice_stream = f"{SYMBOL}@markPrice@{p_markPrice['speed']}s"
kline_stream = f"{SYMBOL}@kline_{p_kline['interval']}"
listenKey = listenKey

## make stream lists
stream = [
    # aggTrade_stream,
    markPrice_stream,
    # kline_stream,
    listenKey,
]
# END

# %%
# defining stream data collector
from trade_rules.trade_callback import Callback
trader = Callback(um_futures_client, current_asset, current_amt, listenKey=listenKey, markPrice=markPrice_stream)
# END

# websocket start
config_logging(logging, logging.DEBUG)

my_client.start()

my_client.live_subscribe(
    stream=stream,
    id=1,
    callback=trader.callback,
)
try:
    time.sleep(15)
except KeyboardInterrupt:
    my_client.stop()

logging.debug("closing ws connection")
my_client.stop()
# Out:
# message :
#  {'id': 1, 'result': None}
# loading...
# ## DEBUG : CALLBACKNUM_markPrice : 1
# ## DEBUG : markPrice 1 received row
#          eventType      eventTime     markPrice    indexPrice
# 0  markPriceUpdate  1675260314000  23085.115376  23085.668955
# ## ERROR : update_ma_condition is not triggered.
# ## DEBUG : ma1>ma2 ?: None
# ## DEBUG : buy/sell condition1: False False
# ## DEBUG : buy/sell decision: False False
# ## DEBUG :
# --- RESULT ---
# --- Initial Asset  : 14911.87067678
# --- Current Asset  : 14911.87067678
# --- Current Amount : 0.0
# --- Entry Price    : 0
# ## DEBUG : CALLBACKNUM_markPrice : 2
# ## DEBUG : markPrice 1 received row
#          eventType      eventTime     markPrice    indexPrice
# 0  markPriceUpdate  1675260315000  23085.559555  23086.113134
# ## ERROR : update_ma_condition is not triggered.
# ## DEBUG : ma1>ma2 ?: None
# ## DEBUG : buy/sell condition1: False False
# ## DEBUG : buy/sell decision: False False
# ## DEBUG :
# --- RESULT ---
# --- Initial Asset  : 14911.87067678
# --- Current Asset  : 14911.87067678
# --- Current Amount : 0.0
# --- Entry Price    : 0
# ## DEBUG : CALLBACKNUM_markPrice : 3
# ## DEBUG : markPrice 1 received row
#          eventType      eventTime     markPrice    indexPrice
# 0  markPriceUpdate  1675260316000  23085.207465  23085.761045
# ## ERROR : update_ma_condition is not triggered.
# ## DEBUG : ma1>ma2 ?: None
# ## DEBUG : buy/sell condition1: False False
# ## DEBUG : buy/sell decision: False False
# ## DEBUG :
# --- RESULT ---
# --- Initial Asset  : 14911.87067678
# --- Current Asset  : 14911.87067678
# --- Current Amount : 0.0
# --- Entry Price    : 0
# ## DEBUG : CALLBACKNUM_markPrice : 4
# ## DEBUG : markPrice 1 received row
#          eventType      eventTime     markPrice    indexPrice
# 0  markPriceUpdate  1675260317000  23084.064413  23084.617992
# ## ERROR : update_ma_condition is not triggered.
# ## DEBUG : ma1>ma2 ?: None
# ## DEBUG : buy/sell condition1: False False
# ## DEBUG : buy/sell decision: False False
# ## DEBUG :
# --- RESULT ---
# --- Initial Asset  : 14911.87067678
# --- Current Asset  : 14911.87067678
# --- Current Amount : 0.0
# --- Entry Price    : 0
# ## DEBUG : CALLBACKNUM_markPrice : 5
# ## DEBUG : markPrice 1 received row
#          eventType      eventTime     markPrice    indexPrice
# 0  markPriceUpdate  1675260318000  23083.723667  23084.277246
# ## ERROR : update_ma_condition is not triggered.
# ## DEBUG : ma1>ma2 ?: None
# ## DEBUG : buy/sell condition1: False False
# ## DEBUG : buy/sell decision: False False
# ## DEBUG :
# --- RESULT ---
# --- Initial Asset  : 14911.87067678
# --- Current Asset  : 14911.87067678
# --- Current Amount : 0.0
# --- Entry Price    : 0
# ## DEBUG : CALLBACKNUM_markPrice : 6
# ## DEBUG : markPrice 1 received row
#          eventType      eventTime     markPrice  indexPrice
# 0  markPriceUpdate  1675260319000  23084.062021  23084.6156
# ## ERROR : update_ma_condition is not triggered.
# ## DEBUG : ma1>ma2 ?: None
# ## DEBUG : buy/sell condition1: False False
# ## DEBUG : buy/sell decision: False False
# ## DEBUG :
# --- RESULT ---
# --- Initial Asset  : 14911.87067678
# --- Current Asset  : 14911.87067678
# --- Current Amount : 0.0
# --- Entry Price    : 0
# ## DEBUG : CALLBACKNUM_markPrice : 7
# ## DEBUG : markPrice 1 received row
#          eventType      eventTime     markPrice    indexPrice
# 0  markPriceUpdate  1675260320000  23083.707847  23084.261426
# ## ERROR : update_ma_condition is not triggered.
# ## DEBUG : ma1>ma2 ?: None
# ## DEBUG : buy/sell condition1: False False
# ## DEBUG : buy/sell decision: False False
# ## DEBUG :
# --- RESULT ---
# --- Initial Asset  : 14911.87067678
# --- Current Asset  : 14911.87067678
# --- Current Amount : 0.0
# --- Entry Price    : 0
# ## DEBUG : CALLBACKNUM_markPrice : 8
# ## DEBUG : markPrice 1 received row
#          eventType      eventTime     markPrice    indexPrice
# 0  markPriceUpdate  1675260321000  23084.014629  23084.568209
# ## ERROR : update_ma_condition is not triggered.
# ## DEBUG : ma1>ma2 ?: None
# ## DEBUG : buy/sell condition1: False False
# ## DEBUG : buy/sell decision: False False
# ## DEBUG :
# --- RESULT ---
# --- Initial Asset  : 14911.87067678
# --- Current Asset  : 14911.87067678
# --- Current Amount : 0.0
# --- Entry Price    : 0
# ## DEBUG : CALLBACKNUM_markPrice : 9
# ## DEBUG : markPrice 1 received row
#          eventType      eventTime     markPrice    indexPrice
# 0  markPriceUpdate  1675260322000  23083.868659  23084.422239
# ## ERROR : update_ma_condition is not triggered.
# ## DEBUG : ma1>ma2 ?: None
# ## DEBUG : buy/sell condition1: False False
# ## DEBUG : buy/sell decision: False False
# ## DEBUG :
# --- RESULT ---
# --- Initial Asset  : 14911.87067678
# --- Current Asset  : 14911.87067678
# --- Current Amount : 0.0
# --- Entry Price    : 0
# ## DEBUG : CALLBACKNUM_markPrice : 10
# ## DEBUG : markPrice 1 received row
#          eventType      eventTime     markPrice    indexPrice
# 0  markPriceUpdate  1675260323001  23084.109778  23084.663358
# ## ERROR : update_ma_condition is not triggered.
# ## DEBUG : ma1>ma2 ?: None
# ## DEBUG : buy/sell condition1: False False
# ## DEBUG : buy/sell decision: False False
# ## DEBUG :
# --- RESULT ---
# --- Initial Asset  : 14911.87067678
# --- Current Asset  : 14911.87067678
# --- Current Amount : 0.0
# --- Entry Price    : 0
# ## DEBUG : CALLBACKNUM_markPrice : 11
# ## DEBUG : markPrice 1 received row
#          eventType      eventTime     markPrice    indexPrice
# 0  markPriceUpdate  1675260324001  23083.944706  23084.498285
# ## ERROR : update_ma_condition is not triggered.
# ## DEBUG : ma1>ma2 ?: None
# ## DEBUG : buy/sell condition1: False False
# ## DEBUG : buy/sell decision: False False
# ## DEBUG :
# --- RESULT ---
# --- Initial Asset  : 14911.87067678
# --- Current Asset  : 14911.87067678
# --- Current Amount : 0.0
# --- Entry Price    : 0
# ## DEBUG : CALLBACKNUM_markPrice : 12
# ## DEBUG : markPrice 1 received row
#          eventType      eventTime     markPrice    indexPrice
# 0  markPriceUpdate  1675260325000  23083.944706  23084.498285
# ## ERROR : update_ma_condition is not triggered.
# ## DEBUG : ma1>ma2 ?: None
# ## DEBUG : buy/sell condition1: False False
# ## DEBUG : buy/sell decision: False False
# ## DEBUG :
# --- RESULT ---
# --- Initial Asset  : 14911.87067678
# --- Current Asset  : 14911.87067678
# --- Current Amount : 0.0
# --- Entry Price    : 0
# ## DEBUG : CALLBACKNUM_markPrice : 13
# ## DEBUG : markPrice 1 received row
#          eventType      eventTime     markPrice   indexPrice
# 0  markPriceUpdate  1675260326000  23083.490081  23084.04366
# ## ERROR : update_ma_condition is not triggered.
# ## DEBUG : ma1>ma2 ?: None
# ## DEBUG : buy/sell condition1: False False
# ## DEBUG : buy/sell decision: False False
# ## DEBUG :
# --- RESULT ---
# --- Initial Asset  : 14911.87067678
# --- Current Asset  : 14911.87067678
# --- Current Amount : 0.0
# --- Entry Price    : 0
# ## DEBUG : CALLBACKNUM_markPrice : 14
# ## DEBUG : markPrice 1 received row
#          eventType      eventTime     markPrice   indexPrice
# 0  markPriceUpdate  1675260327000  23083.490081  23084.04366
# ## ERROR : update_ma_condition is not triggered.
# ## DEBUG : ma1>ma2 ?: None
# ## DEBUG : buy/sell condition1: False False
# ## DEBUG : buy/sell decision: False False
# ## DEBUG :
# --- RESULT ---
# --- Initial Asset  : 14911.87067678
# --- Current Asset  : 14911.87067678
# --- Current Amount : 0.0
# --- Entry Price    : 0

# %%
print("end")
# Out:
# end
